# %%
##Variables

data = ['e1f2d3d3d4', 'e1f2d3d3d4', 'e1f2d3d3d4', 'e1f2d3d3d4']

POPULATION_SIZE = 10
NUM_GENERATIONS = 50

MUTATION_RATE = 0.1

# Define mutation function

allowed_notes = ['c1', 'c2', 'c3', 'c4', 'c5', 'c6', 'c7', 'c8', 'd1', 'd2', 'd3', 'd4', 'd5', 'd6', 'd7', 'd8', 'e1', 'e2', 'e3', 'e4', 'e5', 'e6', 'e7', 'e8', 'f1', 'f2', 'f3', 'f4', 'f5', 'f6', 'f7', 'f8', 'g1', 'g2', 'g3', 'g4', 'g5', 'g6', 'g7', 'g8', 'a1', 'a2', 'a3', 'a4', 'a5', 'a6', 'a7', 'a8', 'b1', 'b2', 'b3', 'b4', 'b5', 'b6', 'b7', 'b8']

# %%
data = []
with open("./data/data.txt", "r") as dataFile:
    lines = dataFile.readlines()
    for l in lines:
        data.append(l.strip().replace(".",""))
data
# Out:
# ['e3e5e4b4',
#  'a3e3e5e4b4',
#  'a3e3e5e4b4',
#  'a3e3e5e4b4',
#  'e3e5e4b4',
#  'a3e3e5e4b4',
#  'e5e4b4',
#  'e5e4b4',
#  'e3e3e2',
#  'd4d3d4d3d4d3e4',
#  'a3c3a3c3a3c3',
#  'e4g5g5g5',
#  'e5e5e5d5d5d5b4b4b4e5b4b4b4b4',
#  'a4a4a4g4g4g4e3e3e2',
#  'd4d3d4d3d4d3e4',
#  'a3c3a3c3a3c3',
#  'b3b3b3b2e5b4g3g3g3g2',
#  'b3b3b3b2a3a3a3a2e4',
#  'b3b3b3b2b3b3b3b2b3b3b3',
#  'e5b4b3b3b3b2',
#  'b3b3b3b2e3e3e2',
#  'd4d3d4d3d4d3e4',
#  'a3c3a3c3a3c3',
#  'e4g5g5g5',
#  'e5e5e5d5d5d5b4b4b4e5b4b4b4b4',
#  'a4a4a4g4g4g4e3e3e2',
#  'd4d3d4d3d4d3e4',
#  'a3c3a3c3a3c3',
#  'b3b3b3b2e5b4g3g3g3g2',
#  'b3b3b3b2a3a3a3a2e4',
#  'b3b3b3b2b3b3b3b2b3b3b3',
#  'e5b4b3b3b3b2',
#  'b3b3b3b2e3e3e2',
#  'd4d3d4d3d4d3e4',
#  'a3c3a3c3a3c3',
#  'e4g5g5g5',
#  'e5e5e5d5d5d5b4b4b4e5b4b4b4b4',
#  'a4a4a4g4g4g4e3e3e2',
#  'd4d3d4d3d4d3e4',
#  'a3c3a3c3a3c3',
#  'b3b3b3b2e5b4g3g3g3g2',
#  'b3b3b3b2a3a3a3a2e4',
#  'b3b3b3b2b3b3b3b2b3b3b3',
#  'e5b4b3b3b3b2',
#  'b3b3b3b2e3e3e2',
#  'd4d3d4d3d4d3e4',
#  'a3c3a3c3a3c3',
#  'e4g5g5g5',
#  'e5e5e5d5d5d5b4b4b4e5b4b4b4b4',
#  'a4a4a4g4g4g4e3e3e2',
#  'd4d3d4d3d4d3e4',
#  'a3c3a3c3a3c3',
#  'b3b3b3b2e5b4g3g3g3g2',
#  'b3b3b3b2a3a3a3a2e4',
#  'b3b3b3b2b3b3b3b2b3b3b3',
#  'e5b4b3b3b3b2',
#  'b3b3b3b2',
#  'a3b3b2b2a3b3b2e5b4e3e3',
#  'b2b3b3b2e4',
#  'a3b3b2a3b3b2e5b4',
#  'b3b3b2b3b3b2',
#  'a3b3b2b2a3a3b2e5b4e3e3b2',
#  'b2b3b3b2e4',
#  'a3a3a2a3a3a2e5b4',
#  'b3b3b2b3b3e2',
#  'a2a2e5b4',
#  'a2a3a3a2e4',
#  'g2g3g3g2e5b4',
#  'a3a3a2a3a3a2',
#  'g3g3a2a2g3g3a2e5b4a2',
#  'a2a3a3a2e4',
#  'g2g3g3g2e5b4',
#  'a3a3a2a3a3a2',
#  'e3e3e2e5b4',
#  'b3b3b2e4a3a3a2',
#  'a3a3a2a2b3b3b2e5b4',
#  'b3b3b2b3b3b2',
#  'a3a3b2e3e3b2e5b4',
#  'b3b3b2e4a3a3a2',
#  'a3a3a2b3b3b2e5b4',
#  'g2g2g2e5b4',
#  'g2c3e5b4',
#  'd3d3e5b4',
#  'e2e3e3e2',
#  'd3d4d3d4d3e4d4',
#  'c3a3c3a3c3e4a3',
#  'g5g5g5e5e5e5d5d5d5e5b4b4b4b4',
#  'b4b4b4a4a4a4g4g4g4e2e4e3e3',
#  'd3d4d3d4d3e4d4',
#  'c3a3c3a3c3e4a3',
#  'b2e5b4b3b3b3g2',
#  'g3g3g3',
#  'b2b3b3b3a2e4a3a3a3',
#  'b2b3b3b3b2b3b3b3',
#  'e5b4b3b3b3b2',
#  'b3b3b3b2b3b3b3b2e4',
#  'a3b3b2b2e5b4a3b3',
#  'e3e3b2b2e4b3b3',
#  'b2a3b3b2e5b4a3b3',
#  'b2b3b3b2e4b3b3',
#  'a3b3b2b2e5b4a3b3b2',
#  'e3e3b2b2e4b3b3',
#  'b2a3b3b2e5b4a3b3',
#  'b2b3b3e2e4b3b3',
#  'b2e5b4',
#  'b2b2e4a3b3',
#  'g2e5b4g3g3',
#  'b2a3b3a2e4a3b3',
#  'g3g3a2a2e5b4g3g3a2',
#  'a2a2e4a3a3',
#  'g2e5b4g3g3',
#  'a2a3a3a2e4a3a3',
#  'a3a3e2e3e3e5b4',
#  'b2b3b3e4a2',
#  'a3a3a2a3a3a2b2e5b4b3b3',
#  'b2b3b3b2e4b3b3',
#  'a3a3e3e3b2e5b4',
#  'b2b3b3e4a2',
#  'a3a3a2a3a3b2e5b4b3b3',
#  'g2g2e4g2',
#  'g2g2e5b4',
#  'g2c3e5b4',
#  'd3e4d3',
#  'd3e5b4',
#  'e3e3e3e3d4d4d4d4a2e4c4c4c4c4',
#  'b3b3b3b3a2',
#  'c4c4c4c4e2g3g3g3g3e5b4b2',
#  'b3b3b3b3b2a3a3a3a3b2e4b3b3b3b3b2',
#  'b3b3b3b3b2b3b3b3b3b2b3b3b3b3b2e5b4b3b3b3b3',
#  'b2e3e3e3e3d4d4d4d4b2e4c4c4c4c4',
#  'b3b3b3b3b2',
#  'c4c4c4c4g3g3g3g3b2e5b4',
#  'b3b3b3b3b2a3a3a3a3b2e4b3b3b3b3',
#  'b3b3b3b3a2b3b3b3b3b3b3b3b3b2e5b4b3b3b3b3',
#  'e2e3e3e3e3d4d4d4d4a2e4c4c4c4c4',
#  'b3b3b3b3a2',
#  'c4c4c4c4g3g3g3g3a2e5b4',
#  'b3b3b3b3a2a3a3a3a3e4b3b3b3b3g2',
#  'b3b3b3b3g2b3b3b3b3b3b3b3b3a2e5b4b3b3b3b3',
#  'a2e3e3e3e3d4d4d4d4a2e4c4c4c4c4',
#  'b3b3b3b3a2',
#  'c4c4c4c4g3g3g3g3a2e5b4',
#  'b3b3b3b3a2a3a3a3a3e4b3b3b3b3g2',
#  'b3b3b3b3g2b3b3b3b3b3b3b3b3a2e5b4b3b3b3b3',
#  'a2a3a3a3a3g4g4g4g4a2e4f4f4f4f4',
#  'e4e4e4e4a2',
#  'f4f4f4f4e2c4c4c4c4e5b4b2',
#  'e4e4e4e4b2d4d4d4d4e4e4e4e4e4a2',
#  'e4e4e4e4a2e4e4e4e4e4e4e4e4b2e5b4e4e4e4e4',
#  'b2a3a3a3a3g4g4g4g4b2e4f4f4f4f4',
#  'e4e4e4e4b2',
#  'f4f4f4f4c4c4c4c4b2e5b4',
#  'e4e4e4e4b2d4d4d4d4e4e4e4e4e4a2',
#  'e4e4e4e4a2e4e4e4e4e4e4e4e4b2e5b4e4e4e4e4',
#  'g2e3e3e3e3d4d4d4d4g2e4c4c4c4c4g2',
#  'b3b3b3b3g2',
#  'c4c4c4c4g2g3g3g3g3g2e5b4',
#  'b3b3b3b3g2a3a3a3a3g2e4b3b3b3b3',
#  'b3b3b3b3g2b3b3b3b3b3b3b3b3c3e5b4b3b3b3b3',
#  'd3e3e3e3e3d4d4d4d4e4c4c4c4c4a3',
#  'b3b3b3b3a3',
#  'c4c4c4c4g3g3g3g3d4e5b4',
#  'b3b3b3b3d4a3a3a3a3e4b3b3b3b3',
#  'b3b3b3b3b3b3b3b3b3b3b3b3e5b4b3b3b3b3',
#  'e3e3e5b4',
#  'd3e4d4d3',
#  'd4d3d4',
#  'c3e4a3c3',
#  'g5g5g5e5b4e5e5e5',
#  'd5d5d5b4b4b4b4b4b4e4a4a4a4',
#  'g4g4g4e2',
#  'e2e5e4b4e3e3',
#  'e2e3e3',
#  'e1e1e1e1e1e1e1g1',
#  'g1e1e1e1e1e1e1a1',
#  'a1e1e1e1e1e1e1d2',
#  'd2e1e1e1e1e1e1e1',
#  'e1e1e1e1e1e1e1g1',
#  'g1e1e1e1e1e1e1a1',
#  'a1e1e1e1e1e1e1d2',
#  'd2e1e1e1e1e1e1e1',
#  'e1e1e1e1e1e1e1g1',
#  'g1e1e1e1e1e1e1a1',
#  'a1e1e1e1e1e1e1d2',
#  'd2e1e1e1e1e1e1e1',
#  'e1e1e1e1e1e1e1g1',
#  'g1e1e1e1e1e1e1a1',
#  'a1e1e1e1e1e1e1d2',
#  'd2e1e1e1e1d2d2e1',
#  'e1e1e1e1e1e1e1e1',
#  'e1e1e1e1e1e1e1e1',
#  'e1e1e1e1e1e1e1e1',
#  'e1e1e1e1e1d2d2e1',
#  'e1e1e1e1e1e1e1e1',
#  'e1e1e1e1e1e1e1e1',
#  'e1e1e1e1e1e1e1e1',
#  'e1e1e1e1e1d2d2e1',
#  'e1e1e1e1e1e1e1e1',
#  'e1e1e1e1e1e1e1e1',
#  'e1e1e1e1e1e1e1e1',
#  'e1e1e1e1e1d2d2e1',
#  'e1e1e1e1e1d2d2e1',
#  'e1e1e1e1e1d2d2e1',
#  'e1e1e1e1e1d2d2e1',
#  'e1e1e1e1e1',
#  'a1a1a1',
#  'e1e1e1e1',
#  'e1d2e2e1',
#  'a1a1a1a1',
#  'a1g1a1',
#  'e1e1e1e1',
#  'e1e1e1e1',
#  'e1e1e1e1',
#  'e1e1e1e1e1d2d2e1',
#  'e1e1e1e1e1e1e1e1',
#  'e1e1e1e1e1e1e1e1',
#  'e1e1e1e1e1e1e1e1',
#  'e1e1e1e1e1d2d2e1',
#  'e1e1e1e1e1e1e1e1',
#  'e1e1e1e1e1e1e1e1',
#  'e1e1e1e1e1e1e1e1',
#  'e1e1e1e1e1d2d2e1',
#  'e1e1e1e1e1e1e1e1',
#  'e1e1e1e1e1e1e1e1',
#  'e1e1e1e1e1e1e1e1',
#  'e1e1e1e1e1d2d2e1',
#  'e1e1e1e1e1d2d2e1',
#  'e1e1e1e1e1d2d2e1',
#  'e1e1e1e1e1d2d2e1',
#  'e1e1e1e1e1',
#  'a1a1a1a1',
#  'a1g1a1',
#  'e1e1e1e1',
#  'a1a1a1a1',
#  'a1g1a1',
#  'e1e1e1e1',
#  'e1e1e1d4e1d4b3b1b1b1b1b1b1b1b1b3b1b1e4b1a1a1a1a1e4a1d4d4b1b1b1b1b1b1d4b1a4b1a4b1b1b1a1a1b4a1a1f4a4a1a4b1b1b1b1b1b1b1b1b1b1b1a1a1a1a1a1',
#  'b1b4b1c5b4b1b1g4f4b1b1',
#  'b1d4b1b3e1d2d4d2d2d4e1',
#  'a5e1e1e1e1e1e1e1e1e1e1e1e1e1e1e1e1e1e1e1e1e1e1e1e1e1e1e1e1e1d2d2e1e1e1e1e1e1e1e1e1e1e1e1e1e1e1e1e1e1e1e1e1e1e1e1e1e1e1e1e1e1d2d2e1e1e1e1e1e1e1e1e1e1e1e1e1e1e1e1e1e1e1e1e1e1e1e1e1e1e1e1e1e1d2d2e1e1e1e1e1e1d2d2e1e1e1e1e1e1d2d2e1e1e1e1e1e1d2d2e1e1e1e1e1e1',
#  'a1a1a1a1a1g1a1e1e1e1e1e1d2e2e1a1a1',
#  'a1a1a1g1a1',
#  'e1e1e1e1e1e1e1e1g1g1e1e1e1a1a1e1e1e1e1d2e2',
#  'e1e1e1e1g1g1e1e1e1a1a1e1e1e1e1d2e2',
#  'd3e1e1',
#  'e1e1g1g1e1e1',
#  'e1a1a1e1e1e1e1d2e2',
#  'd3d3d3d3d3',
#  'd3g4d3d4g4d3f4',
#  'd3d3f3a3',
#  'd3d3d3',
#  'd4g4f4d4',
#  'd3d3a2',
#  'b2d3c2',
#  'a2c3c2',
#  'a2c3c2',
#  'a2c3c2',
#  'b2d3c2',
#  'a2c3c2',
#  'a2c3c2',
#  'a2c3c2',
#  'a2c3c2',
#  'a2c3c2',
#  'a2c3c2',
#  'a2a3c2',
#  'g2d3d2',
#  'g3d4b1',
#  'a4a2d2',
#  'g4d2f5',
#  'e4a2b1',
#  'd5g3c2',
#  'g2d3d2',
#  'f5b2a1',
#  'c5d4b1',
#  'd4d4b1',
#  'g3d4e1',
#  'b4a2g1',
#  'b3a2d2',
#  'd4b2a1',
#  'd4c2e4',
#  'b2g3c2',
#  'a2c3c2',
#  'a2c3c2',
#  'a2c3c2',
#  'a2c3c2',
#  'd3a2d2',
#  'a2c3c2',
#  'a2c3c2',
#  'a2d3d2',
#  'f4c2g3',
#  'f4c2g3',
#  'e4c2g3',
#  'f4c2g3',
#  'g4c2g3',
#  'f4c2g3',
#  'f4c2g3',
#  'e4c2g3',
#  'f4c2g3',
#  'g4c2g3',
#  'f4c2g3',
#  'f4c2g3',
#  'f4c2g3',
#  'e4c2g3',
#  'f4c2g3',
#  'g4c2g3',
#  'f4c2g3',
#  'f4c2g3',
#  'f4c2g3',
#  'e4c2g3',
#  'f4c2g3',
#  'g4c2g3',
#  'f4c2g3',
#  'd4a1e3',
#  'd4a1e3',
#  'c4a1e3',
#  'd4a1e3',
#  'e4a1e3',
#  'd4a1e3',
#  'd4a1e3',
#  'd4a1e3',
#  'c4a1e3',
#  'd4a1e3',
#  'e4a1e3',
#  'd4a1e3',
#  'c4g1g2',
#  'c4g1g2',
#  'b3g1g2',
#  'c4g1g2',
#  'd4g1g2',
#  'c4g1g2',
#  'c4g1g2',
#  'c4g1g2',
#  'b3g1g2',
#  'c4g1g2',
#  'd4g1g2',
#  'c4g1g2',
#  'c4g1g2',
#  'd4g1g2',
#  'c4g1g2',
#  'b3g1g2',
#  'c4g1g2',
#  'd4g1g2',
#  'c4g1g2',
#  'c4g1g2',
#  'c4g1g2',
#  'b3g1g2',
#  'c4g1g2',
#  'd4g1g2',
#  'c4g1g2',
#  'f4c2g3',
#  'f4c2g3',
#  'e4c2g3',
#  'f4c2g3',
#  'g4c2g3',
#  'f4c2g3',
#  'f4c2g3',
#  'f4c2g3',
#  'e4c2g3',
#  'f4c2g3',
#  'g4c2g3',
#  'f4c2g3',
#  'f4c2g3',
#  'f4c2g3',
#  'e4c2g3',
#  'f4c2g3',
#  'g4c2g3',
#  'f4c2g3',
#  'f4c2g3',
#  'f4c2g3',
#  'e4c2g3',
#  'f4c2g3',
#  'g4c2g3',
#  'f4c2g3',
#  'g1d2g1',
#  'g1d2g1',
#  'g1d2g1',
#  'd2g1g1',
#  'c5a1e4',
#  'c5a1e4',
#  'c5a1e4',
#  'b4a1e4',
#  'c5a1e4',
#  'c5a1e4',
#  'c5a1e4',
#  'c5a1e4',
#  'c5a1e4',
#  'b4a1e4',
#  'c5a1e4',
#  'c5a1e4',
#  'g1f2g1',
#  'g1d2g1',
#  'g1d2g1',
#  'g1f2g1',
#  'g1d2g1',
#  'g1d2g1',
#  'g1f2g1',
#  'g1g1d2',
#  'g3c2d2',
#  'c2g1d2',
#  'f3c5c2',
#  'f3c5c2g1',
#  'c5c2g1',
#  'f3c5c2g1',
#  'b2d2g2g1',
#  'c3g2d3g2c3c2g2',
#  'b2g2c3g2d3g1g2',
#  'g2g2c3d2',
#  'c3g2d3',
#  'b2c2g2',
#  'c3g2g1g2d3',
#  'g2c3g1g2',
#  'g2g2g1c3g2d3d2g2',
#  'g1c3g2d3',
#  'g2c3g2',
#  'b2g2c3',
#  'g2d3g2g1g2',
#  'g2b2d2g2g1g2',
#  'c3g2d3',
#  'g2c3c2g2',
#  'b2g2c3',
#  'g2d3g1g2',
#  'c3d2g2',
#  'd3g2c3',
#  'b2d2g2',
#  'b2c2g2',
#  'd3g1g2g2c3g1g2',
#  'c3g1g2',
#  'g2d3g2g1',
#  'g1g2c3g1g2',
#  'd3g2c3g2b2g2c3g2d3g2c3g2b2g1g2c3g2d3g2',
#  'c3g2b2g2c3g2d3g2c3g2b2g1g2c3g2d3g2c3g2b2g2c3g2d3g2c3g2b2g2',
#  'c3g2d3g2c3g2b2g2c3g2d3g2c3g2b2g2c3g2d3g2c3g2b2g2c3g2d3g2c3g2b2g2c3g2d3g2c3g2b2g2c3g2d3g2c3g2b2g2c3g2d3g2c3g2b2g2c3g2d3g2c3g2b2g2c3g2d3g2c3g2b2g2c3g2d3g2c3g2',
#  'b3d4b3',
#  'b3d4b3',
#  'f4b3e4b3e4b3e4b3e4b3e4b3e4',
#  'b3e4b3',
#  'e4b3f4b3e4b3e4b3e4b3e4b3e4b3',
#  'a4b3g4b3a4b3',
#  'e4b3f4b3e4b3e4b3e4b3',
#  'b3b3b3',
#  'b4b3a4b3g4',
#  'b3a4b3g4b3f4b3g4b3e4b3e4b3e4b3e4b3e4b3e4',
#  'b3e4b3',
#  'a4b3g4b3f4b3g4b3e4b3f4b3e4b3e4b3e4b3e4b3e4b3e4',
#  'b3e4b3',
#  'd4a4d4a4a1',
#  'c4c4g3g3g1',
#  'd4g4d4g4g2',
#  'a4a4a1',
#  'g3g3g1',
#  'e4a1a1',
#  'd4a4d4a4a1',
#  'c4c4g3g3g1',
#  'd4g4d4g4g2',
#  'a4a4a1',
#  'g3g3g1',
#  'e4a1a1',
#  'b3e2b3e2e4e4',
#  'e2e4e2',
#  'b3e2b3e2e4e4',
#  'b3e2b3e2e4e4',
#  'b3e2b3e2e4e4',
#  'd4a4d4a4a1',
#  'c4c4g3g3g1',
#  'd4g4d4g4g2',
#  'a4a4a1',
#  'g3g3g1',
#  'e4a1a1',
#  'e5e5e5e5',
#  'g2g5g5',
#  'd2e5e5',
#  'd4a4d4a4a1e5e5',
#  'c4c4g3g3g1e5e5',
#  'd4g4d4g4g2g5g5',
#  'd2e5e5',
#  'a4a4a1e5e5',
#  'g3g3g1e5e5',
#  'e4e4e5e5',
#  'e4a1a1',
#  'd2d2g1',
#  'b3e2e4',
#  'c5e2b4',
#  'b3e2e4',
#  'c5e2b4',
#  'b3e2e4',
#  'c5e2b4',
#  'f4a4c5c5',
#  'a4g4a4',
#  'f4g4a4c5c5',
#  'f4a4c5',
#  'a4a4a4',
#  'e5c5a4a4',
#  'g4a4c5',
#  'a4a4g4',
#  'e5c5e5',
#  'c5a4c5',
#  'b4e2a4',
#  'e2b4e2b4d4e2e2e2',
#  'e2e2e2e2e2f4e2a4e2f4',
#  'a1a1a2a1',
#  'f2f4a4',
#  'a1a1a1a1a1',
#  'g2g4f2',
#  'a1a1a1a1a1',
#  'g2c5a2b4g4a4',
#  'a1a1a1d2a4d2a4',
#  'a4f4c5c5',
#  'a4a4f4a4',
#  'c5a4c5',
#  'f4a4c5c5',
#  'e5c5a4a4',
#  'c5c5e5e5',
#  'f4a4c5',
#  'c5c5b4',
#  'c5e5e5',
#  'c5c5e5',
#  'c5c5c5c5b4',
#  'a4e2b4b4',
#  'g4f4e2e4',
#  'e2e2e2',
#  'e2e2e2',
#  'e2e2e2e2e2f4e2a4e2f4a1a1a1a1a1a1',
#  'g2f2f4a4',
#  'a1a1g4a1',
#  'g2a2a1',
#  'a1a1g4',
#  'a1e1f1',
#  'e1g1d5f1b4a4a1',
#  'a1a1g4a1',
#  'd2a4d2a4',
#  'a4d2d2d2d2',
#  'd2d2d2d2d2d2d2d2',
#  'd2d5d2',
#  'd3d2e5f1g1',
#  'a1a1a1a1',
#  'a1g2f2a1',
#  'd4e4a1e4',
#  'a1d4d4e4a1g4d4',
#  'd4e4e4',
#  'a1d4d2d4e2e4g2d4f2d4e4a1',
#  'a1a1a3d4g4a1',
#  'c4a1a2',
#  'd2e2f3g2f3f3a2e3c3a1',
#  'a1b3a1b3',
#  'c4a4a1b3a1',
#  'b3g4e1a3',
#  'g1e1f3',
#  'g1e3f1g3a1a1a1a3',
#  'a1g3a1a2',
#  'a3g4a1a4',
#  'd2e2e4g2c4',
#  'a3f2f4c4a4a4a1a4a1a4',
#  'g4d2e2',
#  'g2g4c5a4g4',
#  'a2b4g4a4e4a1e4c4b4a3a1a4a3',
#  'a1g4a4',
#  'a4a1a3a1f3a3a1a1f4a1',
#  'g2d4g4f5d4',
#  'd2d4d4',
#  'a1g4d4a1d4d4a1a1d4a1',
#  'a1b4a4',
#  'g2c5g4c5',
#  'f2a4c5c5',
#  'c4a1a3a3a1',
#  'g2c5c5g4a2c5',
#  'e5e5a1e5',
#  'a3a3a1',
#  'a1c4a3a1c4',
#  'b3g2c5c5c4f2a4',
#  'a1a1d4d4c2f4d4d2',
#  'd2a3f3a3',
#  'c4c4e4g4a1',
#  'c2c2e4e4e4',
#  'c2c2e4e4e4',
#  'c2c2e4e4e4',
#  'b1b1g3g3g3',
#  'e2e2c3c3c3',
#  'd4d4d4',
#  'b2b2b2',
#  'e2e2c3c3c3',
#  'b2b2b2',
#  'd2d2e4e4e4',
#  'c2c2d3d3d3',
#  'e2e2d4d4d4',
#  'b2b2b2',
#  'e2e2c3c3c3',
#  'b2b2b2',
#  'd2d2a3d3a3d3a3d3',
#  'e2e2d4d4d4',
#  'd4d4d4',
#  'b2b2b2',
#  'e2e2c3c3c3',
#  'b2b2b2',
#  'c2c2d3d3d3',
#  'e2e2d4d4d4',
#  'e2e2d4d4d4',
#  'd2d2c3c3c3',
#  'c2c2b2b2b2',
#  'c2c2e4e4e4',
#  'e2e2d4d4d4',
#  'e2e2d3d3d3',
#  'b2b2b2',
#  'e2f2e2f2c3c3c3',
#  'b2b2b2',
#  'c2c2b2b2b2',
#  'e2e2b2b2b2',
#  'b2b2b2',
#  'e2e2c3c3c3',
#  'b2b2b2',
#  'd2d2d3a3d3a3d3a3',
#  'e2e2d4d4d4',
#  'b2b2b2',
#  'e2e2c3c3c3',
#  'b2b2b2',
#  'c2c2d3d3d3',
#  'a1a1e3e3e3',
#  'a1a1e3e3e3',
#  'a1a1a1a1',
#  'a1a1b2b2b2',
#  'a1a1c3c3c3',
#  'b2b2b2',
#  'e2e2c3b2c3b2c3b2',
#  'b2b2b2',
#  'e2e2d3d3d3',
#  'b2b2b2',
#  'e2e2c3c3c3',
#  'b2b2b2',
#  'b2b2b2',
#  'e2e2c3b2c3b2c3b2',
#  'b2b2b2',
#  'e2e2d3d3d3',
#  'b2b2b2',
#  'e2e2c3c3c3',
#  'b2b2b2',
#  'a1a1a2a2a2',
#  'b1b1b2b2b2',
#  'a1a1a2a2a2',
#  'a1a1a2a2a2',
#  'b1b1b2b2b2',
#  'a1a1a2a2a2',
#  'a1a1a2a2a2',
#  'b1b1b2b2b2',
#  'a1a1a2a2a2',
#  'd2d2e4e4e4',
#  'a3a3a3',
#  'a2b2a2b2a2b2',
#  'e2e2b2b2b2',
#  'c3c3c3',
#  'g2g2g2',
#  'a2b2a2b2a2b2',
#  'e2e2b2b2b2',
#  'a2a2a2',
#  'd2d2e4e4e4',
#  'a2a2a2',
#  'e2e2b2b2b2',
#  'a4c5d2',
#  'a3a1a2a4',
#  'c2c5e3b1',
#  'c5c5c2',
#  'e5a3f2d5a2',
#  'f2a4e3e2',
#  'a4a4c2',
#  'c5c5c2',
#  'a3a1d5a2a4',
#  'c2c5e3b1',
#  'a3f2a2',
#  'a4e3a4e2',
#  'e5e5g2',
#  'e5e5g2',
#  'e5c4c2d5b3f4',
#  'e2e5c4',
#  'f2d5b3',
#  'f2d5b3',
#  'c2d5b3',
#  'a4c5d2',
#  'a3a1a2a4',
#  'c2c5e3b1',
#  'c5c5c2',
#  'e5a3f2d5a2',
#  'f2a4e3e2',
#  'c5c5c2',
#  'a3a1d5a2',
#  'c2c5e3b1',
#  'a3f2a2',
#  'a4e3a4e2',
#  'e5e5g2',
#  'e5e5g2',
#  'e5c4c2d5b3f4',
#  'e2e5c4',
#  'f2d5b3',
#  'f2d5b3',
#  'c2d5b3',
#  'e1c5c4',
#  'e1a4c4d5d4',
#  'a1d5d4e5e4',
#  'e1e5c4e5g5b3',
#  'g2g5b3e2f5a3',
#  'g3a2c5c4',
#  'd4c2e4',
#  'c2g4a4c4',
#  'a4a4c4',
#  'e4a4c4a2a4',
#  'a4c4f2g4',
#  'e4a4c4e2',
#  'a4c4c2g4a4c4',
#  'a4e5c4',
#  'c2g4e5c4e4',
#  'e2a4e5c4',
#  'e4e5c4a2c5',
#  'e5c4f2b4',
#  'a4e5c4e2',
#  'e5c4c2e4c4',
#  'd2a4e5',
#  'c2g4e5a3e4',
#  'b1a4e5a3',
#  'e4e5a3d2a4',
#  'e5a3c2g4',
#  'e4e5a3b1a4',
#  'e5a3a1g4e5a3',
#  'c2g4e5c4e4',
#  'e2a4e5c4',
#  'e5c4a2e4',
#  'c5e5c4f2',
#  'c5e5c4e2',
#  'd5e5c4c2e5e5c4',
#  'e5a3e5',
#  'e5e5a3e2',
#  'e5e5a3e2',
#  'e5e5a3d2',
#  'e5e5a3c2d5',
#  'c5e4c2b4d4',
#  'e2c5e4',
#  'f2b4d4a4c4',
#  'f2b4d4a4c4',
#  'c2b4d4',
#  'a4c5d2',
#  'a3a1a2a4',
#  'c2c5e3b1',
#  'c5c5c2',
#  'e5f2d5',
#  'f2a4e3e2',
#  'c5c5c2',
#  'a3a1d5a2',
#  'c2c5e3b1',
#  'a3f2a2',
#  'a4e3a4e2',
#  'e2b4g3',
#  'e5e5g2',
#  'e5e5g2',
#  'e4f4d2',
#  'a2a1a2',
#  'a2a1a2',
#  'a2a1a2',
#  'a2a1a2',
#  'a2a1a2',
#  'a2a1a2',
#  'a2a1a2',
#  'a2a1a2',
#  'a2a1a2',
#  'a2a1a2',
#  'a2a1a2',
#  'a2a1a2',
#  'a2a1a2',
#  'a2a1a2',
#  'a2a1a2',
#  'a2a1a2',
#  'a2a1a2',
#  'a2a1a2',
#  'a2a1a2',
#  'a2a1a2',
#  'a2a1a2',
#  'a2a1a2',
#  'a2a1a2',
#  'a2a1a2a1',
#  'a2a1a2a1',
#  'a2a1a2a1',
#  'a2a1a2a1',
#  'a1c6a1',
#  'a1a5a1a5',
#  'a1c6a1',
#  'a1c6a1a5',
#  'a1a5a1a5',
#  'a2a1a2a5a1a5',
#  'a2a1a2a1',
#  'a1c6a1',
#  'a1a5a1a5',
#  'a1c6a1',
#  'a1c6a1a5',
#  'a1a5a1a5',
#  'a2a1a2a5a1a5',
#  'a2a1a2a1',
#  'a1a1a5',
#  'a1c6a1',
#  'a1c6a1c6',
#  'a2a1a2a1',
#  'a1a1c6',
#  'a1a1a5',
#  'a1a1a5',
#  'a2a1a2a1a5',
#  'a1c6a1',
#  'a1a5a1',
#  'a1c6a1c6',
#  'a1c6a1c6',
#  'a1c6a1',
#  'a2a1a2c6a1',
#  'a1c6a1',
#  'a1c6a2a1a2c6',
#  'a1c6a2a1a2',
#  'a1c6a2a1a2a5a1a5',
#  'g1a5g1a5',
#  'g1c6g1',
#  'g1a5g1a5',
#  'g1d2c6',
#  'd2a5d2a5',
#  'd2d2c6',
#  'd2d2b5',
#  'd2a5a1a5',
#  'e2g1e2',
#  'g1g1c6',
#  'g1g1b5',
#  'g1a5a1a5',
#  'e2g1e2',
#  'g1g1c6',
#  'g1g1b5',
#  'g1a5a1a5',
#  'e2g1e2',
#  'g1c6g1c6',
#  'g1g1c6',
#  'g1g1c6g1a5g1c6',
#  'a5g1a5',
#  'a1a2a1a2',
#  'a1a2a1a2',
#  'a1c6a1',
#  'a1c6a1a5',
#  'a1a5a1a5',
#  'a1a5a1',
#  'a1c6a1',
#  'a1c6a1a5',
#  'a1a5a1a5',
#  'a1a5a2a1a2a5',
#  'a1a1a5',
#  'a1a1a5',
#  'a1a2a1a2',
#  'a1c6a1',
#  'a1c6a1a5',
#  'a1a5a1a5',
#  'a1c6a1',
#  'a1c6a1a5',
#  'a1a5a1a5',
#  'a1a5a2a1a2a5',
#  'a1a2a1a2',
#  'a1g5a1a5',
#  'a1a1a5',
#  'a1a1a5',
#  'a1c6a1',
#  'a1c6a1c6',
#  'a1a2a1a2',
#  'a1a5a1c6',
#  'a1a1c6',
#  'a1a1a5',
#  'a1a1a5',
#  'a1a2a1a2',
#  'a1a5a1a5',
#  'a1a5a1c6',
#  'a1a5a1',
#  'a1a2a1a2',
#  'a1a1c6',
#  'a1c6a1c6',
#  'a1c6a1c6',
#  'a1c6a1',
#  'a1c6a1c6',
#  'a2a1a2c6a1',
#  'a2a1a2c6a1a5a2a1a2a5g1',
#  'a5g1a5',
#  'g1c6g1',
#  'g1a5g1a5',
#  'g1d2c6',
#  'd2c6d2c6',
#  'd2d2c6',
#  'd2d2b5',
#  'd2a5a1a5',
#  'g1g1c6',
#  'g1g1b5',
#  'g1a5a1a5',
#  'g1g1c6',
#  'g1g1b5',
#  'g1a5a1a5',
#  'g1g1g1g1g1g1',
#  'a4a1c5c5a1a4',
#  'a4c5a1c5c5',
#  'c5c5a1c5c5',
#  'c5c5a1c5c5c5c5a1c5c5',
#  'c5c5a1c5c5',
#  'c5c5a1c5c5',
#  'c5c5a1c5a4c5a1c5',
#  'c5a1a4a1a4',
#  'a2a1a1a4',
#  'c5a1c5c5a1a4',
#  'c5c5a1c5c5',
#  'c5c5a1c5c5',
#  'c5c5a1c5c5c5c5a1c5c5',
#  'c5c5a1c5c5',
#  'c5c5a1c5a4',
#  'c5a1c5c5a1a4',
#  'a1a1a4',
#  'c5c5a1',
#  'a1a4c5',
#  'c5c5a1',
#  'c5c5a1',
#  'a1a4c5',
#  'c5c5a2a1',
#  'a4a1d5',
#  'a4a1d5',
#  'a1a1f5',
#  'a1e5a1',
#  'a1a1e5',
#  'd5a1c5',
#  'c5a1e5',
#  'a1c5c5',
#  'a1a4a4',
#  'd5a1c5',
#  'c5a1e5',
#  'a1c5c5c5',
#  'a1a4a4',
#  'a2a1g5a1',
#  'a1g5g5g5a1',
#  'g5a1g5g5',
#  'g5g5a1g5g5',
#  'g5g5a1g5g5g5g5a1g5g5',
#  'g5g5a1g5g5',
#  'g5g5a1g5g5',
#  'g5g5a1g5g5g5g5a1g5',
#  'g5g5a1g5g5g5',
#  'a1g5g5',
#  'a1g5g5',
#  'a2a1g5g2',
#  'a5a5a2',
#  'a2a5a5a5a5a2a5',
#  'g5a2a5a5',
#  'a5a5g2a5a5',
#  'g5g5a5a5a5a5a2a5',
#  'g5g5a5a5a5a2a5',
#  'g5a5a2a5a5a2',
#  'a5a5a2a2a5a5g2',
#  'a5a5a5a5a2',
#  'a5a5a5a5',
#  'a5a5a2a5a5a2',
#  'a5a5a2a5a5',
#  'a5e5a2b5',
#  'c5e5a4a2d5',
#  'a2c5e4a4d4a2c4',
#  'c4a2a2e4a3',
#  'd4g1c4c6c4',
#  'g1a3g1c6',
#  'g1c6g1c6',
#  'g1a5g1',
#  'b5g1a5',
#  'g1a5c6',
#  'b5g1c6',
#  'g1a5b5',
#  'e5d2b5',
#  'e5a4d2e5d5',
#  'd2c5e4',
#  'd2e4e4',
#  'd2d2c5',
#  'd2c5d2',
#  'd2c5a1',
#  'a3a3d4c4',
#  'a3a3c4',
#  'a3a3c4d4',
#  'a3a3d4c4',
#  'a3a3c4',
#  'a3a3c4d4',
#  'a3a3d4c4',
#  'a3a3c4',
#  'a3a3c4d4',
#  'a3a3d4c4',
#  'a3a3c4',
#  'a3a3c4d4',
#  'a3a3d4c4',
#  'a3a3c4',
#  'a3a3c4d4',
#  'a3a3d4c4',
#  'a3a3c4',
#  'a1a3a3',
#  'a1a3a3',
#  'd2c4d4',
#  'a1a3a3',
#  'c2d4c4',
#  'a1a3a3',
#  'a2a1c4',
#  'a1a3a1',
#  'a1a3a1c4d4',
#  'a1a3a3a1d4c4',
#  'a1a3a3a1c4',
#  'a1a3a1',
#  'a1a3a1c4d4',
#  'a1a3a3a1d4c4',
#  'a1a3a3a2a1c4',
#  'a1a3a1',
#  ...]

# %%
##Functions!!!

def levenshtein_distance(s, t):
    """
    Calculate the Levenshtein distance between two strings s and t.
    """
    m, n = len(s), len(t)
    d = [[0] * (n+1) for _ in range(m+1)]
    for i in range(m+1):
        d[i][0] = i
    for j in range(n+1):
        d[0][j] = j
    for j in range(1, n+1):
        for i in range(1, m+1):
            if s[i-1] == t[j-1]:
                d[i][j] = d[i-1][j-1]
            else:
                d[i][j] = 1 + min(d[i-1][j], d[i][j-1], d[i-1][j-1])
    return d[m][n]

def string_similarity(s1, s2):
    """
    Calculate the similarity between two strings s1 and s2 using the Levenshtein distance algorithm.
    The similarity is the inverse of the Levenshtein distance normalized by the length of the longer string.
    """
    distance = levenshtein_distance(s1, s2)
    max_len = max(len(s1), len(s2))
    min_len = min(len(s1), len(s2))
    similarity = 1 - (distance / max_len)
    return similarity

def checker(s1):
    max_score = 0
    for thing in data:
        score = string_similarity(s1, thing)
        if score > max_score:
            max_score=score
    return max_score
    

###ALL of the above is the Fitness! Jonahs Fitness!!!


def crossover(parent1, parent2):
    midpoint = random.randint(0, len(parent1))
 
    child = parent1[:midpoint] + parent2[midpoint:]
    return str(child)



def mutate(s1):
    notes = list(s1)
    for i in range(len(notes)//2):
        if random.random() < MUTATION_RATE:
            rand_choice = randomInRange(len(allowed_notes))
            notes[i*2] = allowed_notes[rand_choice][0]
            notes[i*2+1] = allowed_notes[rand_choice][1]
    return "".join(notes)


# Main genetic algorithm loop

def randomNoteSize():
    return random.randint(3,7)

def randomInRange(upper):
    return random.randint(0, upper-1)
    
def makeInitialPopulation():
    init_population = []
    for i in range(POPULATION_SIZE):
        temp = ""
        for j in range(randomNoteSize()):
            chord = randomInRange(len(data))
            note = randomInRange(len(data[chord])//2)
         
            noteSym = data[chord][(note)*2:note*2+2]
            temp = temp + noteSym
        init_population.append(temp)
        temp = []

    return init_population

# %%
mutate("a1a2b4g3g5")
# Out:
# 'a1a2c4g3f3'

# %%
##Step 1 - Make initial Population

init_population = makeInitialPopulation()

population = init_population
for generation in range(NUM_GENERATIONS):
    print("Generation: " + str(generation))

    
    # Calculate fitness scores for each individual in population
    fitness_scores = [checker(individual) for individual in population]
    
    parents = population
    for i in range(POPULATION_SIZE):
        for j in range(POPULATION_SIZE):
            if fitness_scores[i] > fitness_scores[j]:
                tempr = fitness_scores[i]
                fitness_scores[i] = fitness_scores[j]
                fitness_scores[j] = tempr                
                tempPar = parents[i]
                parents[i] = parents[j]
            
                parents[j] = tempPar
                
                
    # Select top individuals to be parents for next generation

    # Generate next generation through crossover and mutation
    next_gen = parents[:POPULATION_SIZE//2]

    while len(next_gen) < POPULATION_SIZE:
        parent1 = random.choice(parents)
        parent2 = random.choice(parents)
      
        child = crossover(parent1, parent2)
    
        child = mutate(child)
       
        next_gen.append(child)
    
    # Update population for next generation
    population = next_gen[:]

# Print final best individual
# Out:
# Generation: 0
# Generation: 1
# Generation: 2
# Generation: 3
# Generation: 4
# Generation: 5
# Generation: 6
# Generation: 7
# Generation: 8
# Generation: 9
# Generation: 10
# Generation: 11
# Generation: 12
# Generation: 13
# Generation: 14
# Generation: 15
# Generation: 16
# Generation: 17
# Generation: 18
# Generation: 19
# Generation: 20
# Generation: 21
# Generation: 22
# Generation: 23
# Generation: 24
# Generation: 25
# Generation: 26
# Generation: 27
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[145], line 11
#       7 print("Generation: " + str(generation))
#      10 # Calculate fitness scores for each individual in population
# ---> 11 fitness_scores = [checker(individual) for individual in population]
#      13 parents = population
#      14 for i in range(POPULATION_SIZE):
#
# Cell In[145], line 11, in <listcomp>(.0)
#       7 print("Generation: " + str(generation))
#      10 # Calculate fitness scores for each individual in population
# ---> 11 fitness_scores = [checker(individual) for individual in population]
#      13 parents = population
#      14 for i in range(POPULATION_SIZE):
#
# Cell In[141], line 35, in checker(s1)
#      33 max_score = 0
#      34 for thing in data:
# ---> 35     score = string_similarity(s1, thing)
#      36     if score > max_score:
#      37         max_score=score
#
# Cell In[141], line 26, in string_similarity(s1, s2)
#      21 def string_similarity(s1, s2):
#      22     """
#      23     Calculate the similarity between two strings s1 and s2 using the Levenshtein distance algorithm.
#      24     The similarity is the inverse of the Levenshtein distance normalized by the length of the longer string.
#      25     """
# ---> 26     distance = levenshtein_distance(s1, s2)
#      27     max_len = max(len(s1), len(s2))
#      28     min_len = min(len(s1), len(s2))
#
# Cell In[141], line 18, in levenshtein_distance(s, t)
#      16             d[i][j] = d[i-1][j-1]
#      17         else:
# ---> 18             d[i][j] = 1 + min(d[i-1][j], d[i][j-1], d[i-1][j-1])
#      19 return d[m][n]
#
# KeyboardInterrupt:

# %%
population
# Out:
# ['g2c3c2g2',
#  'g2c3c2g2',
#  'g2c3c2g2',
#  'g2c3c2g2',
#  'g2c3c2g2',
#  'g2c3c2c1',
#  'g2c3c2g2',
#  'f7c3c2g2',
#  'g2c3c2g2',
#  'g2c3c2g2']
